# %% [markdown]
# # Recommender systems

# %% [markdown]
# ## Metacritic dataset

# %% [markdown]
# ### Caricamento librerie

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score

import networkx as nx

from re import sub

# %%
stop = stopwords.words("english")
stop.append("expand")

# %% [markdown]
# ### Caricamento dataset

# %%
df = pd.read_json("data/metacritic_data.json")

# %%
df.sample(10)
# Out:
#                                               name platform  \
# 680                         Star Wars: Starfighter      PS2
# 11674                      Joe Danger 2: The Movie      PS3
# 15642  Gravity Falls: Legend of the Gnome Gemulets      3DS
# 4201                 Tak: The Great Juju Challenge     XBOX
# 17694                                    For Honor       PC
# 14953                                The Escapists     XONE
# 14131                Nintendo Pocket Football Club      3DS
# 12102                  Darksiders II: Argul's Tomb     X360
# 19774                         The Spectrum Retreat     XONE
# 18671               Bubsy: The Woolies Strike Back       PC
#
#                  developer    publisher          genre(s)  \
# 680              LucasArts    LucasArts        Simulation
# 11674          Hello Games  Hello Games            Action
# 15642        Ubisoft Osaka      Ubisoft            Action
# 4201    Avalanche Software          THQ            Action
# 17694     Ubisoft Montreal      Ubisoft  Action Adventure
# 14953  Mouldy Toof Studios      Team 17            Action
# 14131            ParityBit     Nintendo            Sports
# 12102          Vigil Games          THQ  Action Adventure
# 19774    Dan Smith Studios     Ripstone         Adventure
# 18671   Black Forest Games     Accolade            Action
#
#                      players rating attribute  \
# 680                 1 Player      T      None
# 11674                   None      E      None
# 15642                   None      E      None
# 4201                    1-2       E      None
# 17694     Online Multiplayer      M      None
# 14953                   None      T      None
# 14131                   None   None      None
# 12102                   None      M      None
# 19774  No Online Multiplayer      T      None
# 18671  No Online Multiplayer      E      None
#
#                                                  summary  release_date  \
# 680    One of the most eagerly anticipated PS2 titles...  Feb 19, 2001
# 11674  On the set of the greatest blockbuster "Movie"...  Oct  9, 2012
# 15642  Gravity Falls: Legend of the Gnome Gemulets, p...  Oct 20, 2015
# 4201   The third chapter in THQ's Tak series lets the...  Sep 19, 2005
# 17694  For Honor is a competitive third-person melee ...  Feb 13, 2017
# 14953  Plot an intricate prison escape while working ...  Feb 13, 2015
# 14131  Head up your own football team and shoot for t...  Apr 17, 2014
# 12102  Argul’s Tomb is a new gameplay zone, which inc...  Sep 25, 2012
# 19774  A challenging, first-person puzzle game set in...  Jul 13, 2018
# 18671  Watch Bubsy glide like a bat, jump like a jack...  Oct 31, 2017
#
#                                                     link  critic_positive  \
# 680            /game/playstation-2/star-wars-starfighter               21
# 11674         /game/playstation-3/joe-danger-2-the-movie                7
# 15642  /game/3ds/gravity-falls-legend-of-the-gnome-ge...                0
# 4201             /game/xbox/tak-the-great-juju-challenge               13
# 17694                                 /game/pc/for-honor               20
# 14953                       /game/xbox-one/the-escapists               18
# 14131            /game/3ds/nintendo-pocket-football-club                7
# 12102           /game/xbox-360/darksiders-ii-arguls-tomb                0
# 19774                /game/xbox-one/the-spectrum-retreat                4
# 18671             /game/pc/bubsy-the-woolies-strike-back                0
#
#        critic_neutral  critic_negative  metascore  user_positive  \
# 680                 4                0         84              9
# 11674               2                0         78              0
# 15642               1                3         46              1
# 4201                6                0         75              0
# 17694              11                0         76             72
# 14953              13                0         74              7
# 14131              21                1         65              5
# 12102               6                0         64              1
# 19774               6                0         69              1
# 18671               2                6         44              6
#
#        user_neutral  user_negative user_score
# 680               1              0        8.0
# 11674             0              2        5.8
# 15642             2              2        6.1
# 4201              1              0        tbd
# 17694            40            110        5.2
# 14953             1              1        6.7
# 14131             2              0        7.4
# 12102             0              0        7.2
# 19774             1              0        6.0
# 18671             0              7        4.8

# %% [markdown]
# ### Selezione giochi appartenenti all'attuale generazione di console

# %%
consoles = ["PS4", "XONE", "Switch"]
df = df[df["platform"].isin(consoles)]

# %% [markdown]
# ### Creazione nuove features

# %%
df["# critic"] = df["critic_positive"] + df["critic_neutral"] + df["critic_negative"]
df["# users"] = df["user_positive"] + df["user_neutral"] + df["user_negative"]

# %% [markdown]
# ### Selezione feature da processare

# %%
df = df[["name", "platform", "developer", "publisher", "genre(s)", "players", "rating", "summary"]]

# %%
df.head()
# Out:
#                 name platform        developer        publisher genre(s)  \
# 12412         flower      PS4  Bluepoint Games             SCEA  General
# 12426        FIFA 14     XONE        EA Canada        EA Sports      Sim
# 12447        FIFA 14      PS4        EA Canada        EA Sports   Sports
# 12459       NBA 2K14     XONE  Visual Concepts        2K Sports      Sim
# 12481  Battlefield 4      PS4          EA DICE  Electronic Arts   Action
#
#          players rating                                            summary
# 12412   1 Player      E  The pioneers that brought you the PLAYSTATION ...
# 12426  Up to 22       E  Shooting has been transformed. Players now hav...
# 12447  Up to 22       E  Fuelled by EA SPORTS IGNITE, FIFA 14 feels ali...
# 12459  Up to 10       E  NBA 2K14 promises to raise the bar yet again, ...
# 12481  Up to 64       M  Battlefield 4 is an action blockbuster that ai...

# %% [markdown]
# ### Preparazione colonna platform

# %%
df["platform"].unique()
# Out:
# array(['PS4', 'XONE', 'Switch'], dtype=object)

# %%
map_platform = {"PS4": 2, "XONE": 1, "Switch": 0}
df["platform"] = df["platform"].map(map_platform)

# %% [markdown]
# ### Preparazione colonna players

# %%
df["players"].value_counts()
# Out:
# No Online Multiplayer    1419
# Up to 4                   200
# 2                         169
# Up to 8                   110
# Up to 6                    67
# Online Multiplayer         61
# Up to 12                   47
# Up to 10                   42
# Up to 16                   38
# Up to 22                   17
# Up to 64                   13
# Up to 5                    12
# Massively Multiplayer      12
# Up to 18                   11
# Up to 3                    11
# Up to 24                   10
# Up to 32                    9
# Up to 40                    9
# Up to 20                    7
# Up to more than 64          5
# Up to 30                    3
# 1 Player                    3
#                             3
# Up to 9                     2
# 1-2                         1
# Name: players, dtype: int64

# %%
df["players"] = df["players"].apply(lambda x: 0 if x == "No Online Multiplayer" else 1)

# %% [markdown]
# ### Preparazione colonna rating

# %%
df["rating"].unique()
# Out:
# array(['E', 'M', 'E10+', 'T', None], dtype=object)

# %%
map_rating = {"E": 0, "E10+": 1, "T": 2, "M": 3, None: -1}
df["rating"] = df["rating"].map(map_rating)

# %% [markdown]
# ### Creazione colonna testi

# %%
df["text"] = df["developer"] + " " + df["publisher"]+ " " + df["genre(s)"] + " " + df["summary"]

# %% [markdown]
# ### Preparazione colonna text

# %%
def clean_text(row):
    try:
        text = sub(r"[^\w\s]", " ", row)
        return " ".join([word.lower() for word in word_tokenize(text)
                         if word not in stop])
    except Exception:
        return row

# %%
df["text"] = df["text"].apply(clean_text)

# %% [markdown]
# ### Selezione feature da inserire nel modello

# %%
df = df[["name", "platform", "players", "rating", "text"]]
df.dropna(subset=["text"], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#             name  platform  players  rating  \
# 0         flower         2        1       0
# 1        FIFA 14         1        1       0
# 2        FIFA 14         2        1       0
# 3       NBA 2K14         1        1       0
# 4  Battlefield 4         2        1       3
#
#                                                 text
# 0  bluepoint games scea general the pioneers brou...
# 1  ea canada ea sports sim shooting transformed p...
# 2  ea canada ea sports sports fuelled ea sports i...
# 3  visual concepts 2k sports sim nba 2k14 promise...
# 4  ea dice electronic arts action battlefield 4 a...

# %% [markdown]
# ### Vettorizzazione testi

# %%
tfidf = TfidfVectorizer(strip_accents="unicode", ngram_range=(1, 2), max_features=6250)

# %%
text = tfidf.fit_transform(df["text"])

# %% [markdown]
# ### Creazione matrice features

# %%
X = np.c_[df["platform"].values, df["players"].values, df["rating"].values, text.todense()]

# %% [markdown]
# ### Clustering

# %% [markdown]
# ### Riduzione dimensionalità matrice

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1])
plt.grid()
plt.show()

# %% [markdown]
# ### K-Means

# %%
scores = []
for k in range(2, 20):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_tsne)
    scores.append({"k": k, "sse": km.inertia_, "score": silhouette_score(X_tsne, km.labels_)})

# %%
data = pd.DataFrame(scores)
data
# Out:
#      k     score           sse
# 0    2  0.383805  6.033090e+06
# 1    3  0.436186  3.662814e+06
# 2    4  0.450885  2.515594e+06
# 3    5  0.505614  1.801392e+06
# 4    6  0.504339  1.408122e+06
# 5    7  0.543804  1.106601e+06
# 6    8  0.582684  8.081818e+05
# 7    9  0.602249  6.316648e+05
# 8   10  0.574604  5.539417e+05
# 9   11  0.564999  5.054654e+05
# 10  12  0.527037  4.640295e+05
# 11  13  0.503204  4.158393e+05
# 12  14  0.480707  3.814259e+05
# 13  15  0.472890  3.578489e+05
# 14  16  0.467625  3.310080e+05
# 15  17  0.478331  3.071130e+05
# 16  18  0.469464  2.879981e+05
# 17  19  0.477880  2.548332e+05

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="k", y="score", data=data)
sns.scatterplot(x="k", y="score", data=data)
plt.title("Silhouette Score", fontsize=15)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.grid()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="k", y="sse", data=data)
sns.scatterplot(x="k", y="sse", data=data)
plt.title("Elbow Method", fontsize=15)
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.grid()
plt.tight_layout()
plt.show()

# %%
km = KMeans(n_clusters=9, random_state=42)
km.fit(X_tsne)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=9, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)

# %% [markdown]
# ### Visualizzazione grafica cluster

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=km.labels_, 
                palette="tab10", legend="full")
plt.grid()
plt.show()

# %% [markdown]
# ### KNN non supervisionato

# %% [markdown]
# ### Fit del modello NearestNeighbors sui dati

# %%
nn = NearestNeighbors(metric="cosine")
nn.fit(X)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=None, n_neighbors=5, p=2, radius=1.0)

# %% [markdown]
# ### Estrazione grafo vicini

# %%
adj_matrix = nn.kneighbors_graph(X)
adj_matrix
# Out:
# <3720x3720 sparse matrix of type '<class 'numpy.float64'>'
# 	with 18600 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Creazione grafo networkx

# %%
G = nx.from_scipy_sparse_matrix(adj_matrix)

# %% [markdown]
# ### Calcolo posizione nodi

# %%
pos = nx.spring_layout(G)

# %% [markdown]
# ### Visualizzazione grafo

# %%
plt.figure(figsize=(15, 15))
# nodes
node_size = [G.degree(node) * 10 for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color=km.labels_, alpha=0.7, edgecolors="white")
# edges
nx.draw_networkx_edges(G, pos, edge_color="lightgray")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Calcolo dei 5 elementi più vicini per ogni elemento

# %%
distances, indices = nn.kneighbors(X, n_neighbors=11)

# %%
distances, indices
# Out:
# (array([[0.        , 0.07474123, 0.15117151, ..., 0.15503109, 0.15601523,
#          0.15675009],
#         [0.        , 0.25934696, 0.25940495, ..., 0.27657336, 0.27733066,
#          0.27895539],
#         [0.        , 0.12296507, 0.13278481, ..., 0.14657694, 0.14709715,
#          0.14768745],
#         ...,
#         [0.        , 0.12941536, 0.13233446, ..., 0.13529759, 0.13610304,
#          0.13682112],
#         [0.        , 0.05336277, 0.05505813, ..., 0.06319972, 0.06372905,
#          0.06408873],
#         [0.        , 0.09438657, 0.09498758, ..., 0.09792635, 0.09812567,
#          0.09819839]]), array([[   0,  322, 1339, ...,  717, 1479, 2479],
#         [   1,  385,    2, ..., 3075,  282,  190],
#         [   2,  385,  115, ..., 1710,   52,  717],
#         ...,
#         [3717, 3652, 1985, ..., 3530, 3699, 1833],
#         [3718, 2746,  575, ...,  557, 3407,  892],
#         [3719, 2545, 2804, ..., 1759, 3428, 2969]]))

# %% [markdown]
# ### Visualizzazione raccomandazione per The Legend of Zelda

# %%
df[df["name"].str.contains("Zelda")]
# Out:
#                                                    name  platform  players  \
# 1590            The Legend of Zelda: Breath of the Wild         0        0
# 1751  The Legend of Zelda: Breath of the Wild - The ...         0        1
# 1839  The Legend of Zelda: Breath of the Wild - The ...         0        1
#
#       rating                                               text
# 1590       1  nintendo nintendo action adventure forget ever...
# 1751       1  nintendo nintendo action adventure new adventu...
# 1839       1  nintendo nintendo action adventure the master ...

# %%
def get_recommendations(dataframe, game_index, model_neighbors):
    return [dataframe.iloc[game][0] for game in model_neighbors[game_index]][1:]

# %%
get_recommendations(dataframe=df, game_index=1590, model_neighbors=indices)
# Out:
# ['Hyrule Warriors: Definitive Edition',
#  'The Elder Scrolls V: Skyrim',
#  'The Long Reach',
#  'Furi',
#  "Wasteland 2: Director's Cut",
#  'Gone Home',
#  'The End Is Nigh',
#  "Don't Knock Twice",
#  'Bayonetta',
#  'Garage']
